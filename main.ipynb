# %%
# !python mlt.py
# Out:
# Hello!
#
# The answer is: Hola (Spanish)
#
# In Spanish, "hello" is translated as "Hola".

# %%
# !streamlit run mlt.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.16.1.21:8501
#
# ^C
#   Stopping...

# %%
# !pip install decouple
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for decouple: filename=decouple-0.0.7-py3-none-any.whl size=4467 sha256=acb7241d4c40fafdb5138ca86d81a237987a8d5fa0eb6fd3625d07d55570d171
#   Stored in directory: /home/pradeep/.cache/pip/wheels/96/25/a4/334fce385701f202e75f7850de1601a7a1b89b16228ee0882b
# Successfully built decouple
# ...

# %%
# !streamlit run textsummarizer.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.16.1.21:8501
#
# /home/pradeep/anaconda3/envs/.venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ^C
#   Stopping...

# %%
# !streamlit run contentrecommender.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.16.1.21:8501
#
# ^C
#   Stopping...

# %%
# !streamlit run audiototextsummarizer.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.16.1.21:8501
#
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722253091.339446  429518 config.cc:230] gRPC experiments enabled: call_status_override_on_cancellation, event_engine_dns, event_engine_listener, http2_stats_fix, monitoring_experiment, pick_first_new, trace_record_callops, work_serializer_clears_time_cache
# 2024-07-29 17:08:12.908 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/pradeep/anaconda3/envs/codellama/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 75, in exec_func_with_error_handling
#     result = func()
#              ^^^^^^
#   File "/home/pradeep/anaconda3/envs/codellama/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 574, in code_to_exec
#     exec(code, module.__dict__)
# ...

# %%
# !pip install pydub

# %%
# !python audiototextsummarizer.py
# Out:
# ...
# tokenizer_config.json: 100%|████████████████████| 163/163 [00:00<00:00, 826kB/s]
# config.json: 100%|█████████████████████████| 1.60k/1.60k [00:00<00:00, 6.36MB/s]
# vocab.json: 100%|██████████████████████████████| 291/291 [00:00<00:00, 1.02MB/s]
# special_tokens_map.json: 100%|████████████████| 85.0/85.0 [00:00<00:00, 450kB/s]
# model.safetensors: 100%|█████████████████████| 378M/378M [00:29<00:00, 12.7MB/s]
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# !python llm_game.py
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2024-07-31 15:37:42,844 - INFO - AI paddle updated to: 202
# 2024-07-31 15:37:42,859 - INFO - AI paddle updated to: 194
# 2024-07-31 15:37:42,876 - INFO - AI paddle updated to: 196
# 2024-07-31 15:37:42,891 - INFO - AI paddle updated to: 188
# 2024-07-31 15:37:42,908 - INFO - AI paddle updated to: 180
# 2024-07-31 15:37:42,925 - INFO - AI paddle updated to: 177
# 2024-07-31 15:37:42,941 - INFO - AI paddle updated to: 169
# 2024-07-31 15:37:42,957 - INFO - AI paddle updated to: 171
# 2024-07-31 15:37:42,972 - INFO - AI paddle updated to: 169
# 2024-07-31 15:37:42,989 - INFO - AI paddle updated to: 167
# 2024-07-31 15:37:43,005 - INFO - AI paddle updated to: 165
# 2024-07-31 15:37:43,021 - INFO - AI paddle updated to: 163
# 2024-07-31 15:37:43,037 - INFO - AI paddle updated to: 161
# 2024-07-31 15:37:43,053 - INFO - AI paddle updated to: 159
# ...

# %%
# !pip install pygame
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 9.4 MB/s eta 0:00:00:00:0100:01
# ...
